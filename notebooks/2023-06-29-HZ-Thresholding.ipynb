# %% [markdown]
# ### Thresholding
#
# *Last Updated*: 2023-06-29
#
# ### Authors
# * Hannah Zhang (hannahzhang@ucsb.edu)
#
#
# ### Overview
# This Jupyter notebook is intended to demonstrate
#
# * thresholding for image segmentation
#
# * https://towardsdatascience.com/how-to-perform-image-segmentation-with-thresholding-using-opencv-b2a78abb07ac
#
#
#
# ### Key Results
#
# -

# %%
import cv2 
import matplotlib.pyplot as plt 
from numpy import asarray

image = cv2.imread("/Applications/DermaML/16B45EFF-7F1D-4437-B8FA-C7D4ADBF4F92.jpeg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

(T, thresh) = cv2.threshold(blurred, 45, 255, cv2.THRESH_BINARY)

#does not generate hand textures

RGB_thresh = cv2.cvtColor(thresh, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_thresh)

#cv2.imwrite('a.jpg', thresh)

# %%
(T, threshInv) = cv2.threshold(blurred, 45, 255, cv2.THRESH_BINARY_INV)

RGB_threshInv = cv2.cvtColor(threshInv, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_threshInv)

# %%
(T, threshOtsu) = cv2.threshold(blurred, 0, 255, 
                cv2.THRESH_BINARY | cv2.THRESH_OTSU)

#generates details in hand outline
RGB_threshOtsu = cv2.cvtColor(threshOtsu, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_threshOtsu)

#cv2.imwrite("au.jpg", threshOtsu)

# %%
masked1 = cv2.bitwise_and(image, image, mask=threshOtsu)

RGB_masked1 = cv2.cvtColor(masked1, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_masked1)

#cv2.imwrite('amasked.jpg', masked1)

# %%
thresh = cv2.adaptiveThreshold(blurred, 255, 
                               cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                              cv2.THRESH_BINARY, 17, 3)

RGB_thresh = cv2.cvtColor(thresh, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_thresh)

#cv2.imwrite('a1.jpg', thresh)
